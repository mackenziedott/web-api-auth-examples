# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('MackPlaylistSongs.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1374 entries, 0 to 1373
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   num_samples                1374 non-null   int64
#  1   duration                   1374 non-null   float64
#  2   offset_seconds             1374 non-null   int64
#  3   window_seconds             1374 non-null   int64
#  4   analysis_sample_rate       1374 non-null   int64
#  5   analysis_channels          1374 non-null   int64
#  6   end_of_fade_in             1374 non-null   float64
#  7   start_of_fade_out          1374 non-null   float64
#  8   loudness                   1374 non-null   float64
#  9   tempo                      1374 non-null   float64
#  10  tempo_confidence           1374 non-null   float64
#  11  time_signature             1374 non-null   int64
#  12  time_signature_confidence  1374 non-null   float64
# ...

# %%
data_col = ['loudness', 'tempo', 'time_signature', 'key', 'mode', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence']
pair_col = ['loudness', 'tempo', 'acousticness', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence']
norm_col = ['loudness', 'acousticness', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence']

# %%
sns.histplot(data = df, x = 'energy')
# Out:
# <AxesSubplot:xlabel='energy', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'liveness')
# Out:
# <AxesSubplot:xlabel='liveness', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'valence')
# Out:
# <AxesSubplot:xlabel='valence', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'danceability')
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'tempo')
# Out:
# <AxesSubplot:xlabel='tempo', ylabel='Count'>

# %%
df_data = df[data_col]
df_pair = df[pair_col]

# %%
sns.pairplot(df_pair)

# %%
sns.boxplot(data = df_pair.drop('tempo'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 sns.boxplot(data = df_pair.drop('tempo'))
#
# File ~\anaconda3\envs\spotifyPlay\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\spotifyPlay\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %% [markdown]
# Lets try Clustering

# %%
from sklearn.cluster import KMeans
from
